# %% [markdown]
# **UE22MA242A: Mathematics for Computer Science Engineers**
#
# Python tutorial: Central limit Theorem
#
# By:- Archishman VB (TA-MCSE)

# %% [markdown]
# # **Central Limit Theorem**
#
# The Central Limit Theorem (CLT) is a fundamental statistical principle that states that, regardless of the original distribution of a population, the sampling distribution of the sample mean will approximate a normal distribution as the sample size becomes sufficiently large.
#
# **Conditions of the Central Limit Theorem**
#
# 1. The sample size is sufficiently large. This condition is usually met if the size of the sample is n ≥ 30.
#
# 2. The samples are independent and identically distributed, i.e., random variables. The sampling should be random.
#
# 3. The population’s distribution has a finite variance. The central limit theorem doesn’t apply to distributions with infinite variance.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Given a dataset with unknown distribution (it could be uniform, binomial or completely random), the sample means will approximate the normal distribution.
#
# These samples should be sufficient in size. The distribution of sample means, calculated from repeated sampling, will tend to normality as the size of your samples gets larger.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **The Data Analysts’ Quest for Traffic Insights**
#
# In the bustling world of digital analytics, a team of data analysts at a fast-growing tech company was given a critical task: to uncover hidden patterns in the website traffic data. With mounting pressure to optimize their online presence and ensure smooth user experiences, the analysts had to rely on advanced statistical techniques to provide actionable insights.

# %%
##TASK-1
##Load the dataset (csv file) using pandas and perform EDA to check for missing values and outliters.
##if there are any missing values, remove the rows with a suitable function.
##after cleaning the data, store the dataframe in a variable -> 'data_cleaned'

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##TASK-2
##Calculate the true population mean of the 'Visits' column
##use a suitable function

# %%
##Plotting the histogram for the 'visits' column
##observe the histogram of the values of the 'Visit' column (look at the distribution of values)
plt.figure(figsize=(10, 6))
sns.histplot(data_cleaned['Visits'], bins=30, kde=True, color='purple')
plt.title('Histogram of Visits')
plt.xlabel('Number of Visits')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# The task is to demonstrate the **Central Limit Theorem (CLT)** using the website traffic data. The analysts knew that the CLT is fundamental to understanding how sample means behave, especially when dealing with random fluctuations in data. This was particularly relevant when trying to make inferences from traffic metrics that could vary significantly day-to-day.
#
# **Goal**: They need to show how sample means from the visits column of the traffic data would converge to a normal distribution, regardless of the original data's distribution. By drawing samples of different sizes (10, 30, and 100) and plotting the distribution of these sample means, they could visually prove the CLT in action.

# %% [markdown]
# Complete the '**plot_sample_means**' function to plot the distibution of sample means of different sizes.
#
# code the values for sample means here. use random sampling , sample it for the sample_size and store the sample means in a list variable-> 'sample_means'

# %%
##TASK-3
##Function to simulate and plot sample means for a given sample size
def plot_sample_means(data_column, sample_size, num_samples=1000):
    sample_means = ###


    plt.figure(figsize=(10, 6))
    sns.histplot(sample_means, kde=True, bins=30, color='skyblue')
    plt.title(f'Sample Means Distribution (Sample Size = {sample_size})')
    plt.xlabel('Sample Mean')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()


##hint : iterate over the number of samples and perform random sampling, find the mean of these samples and store them in sample_means list.

# %%
# Plot for sample size = 10
plot_sample_means(data_cleaned['Visits'], sample_size=10)

# Plot for sample size = 30
plot_sample_means(data_cleaned['Visits'], sample_size=30)

# Plot for sample size = 100
plot_sample_means(data_cleaned['Visits'], sample_size=100)

# %% [markdown]
# Answer the following questions based on the above exercise
#
# **Question 1**: How does the distribution of sample means change as the sample size increases, and what does this tell you about the Central Limit Theorem (CLT) in the context of website traffic data?
#
# **Question 2**: In the context of website traffic analysis, why is understanding the Central Limit Theorem important for making data-driven decisions, especially when dealing with fluctuating traffic patterns?
