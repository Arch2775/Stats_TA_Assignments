# %% [markdown]
# **UE22MA242A: Mathematics for Computer Science Engineers**
#
# Python tutorial: Type-I, Type-II errors
#
# By:- Archishman VB (TA-MCSE)

# %% [markdown]
# # Type I and Type II Errors
#
# **Type 1 errors** – often assimilated with false positives – happens in hypothesis testing when the null hypothesis is true but rejected. The null hypothesis is a general statement or default position that there is no relationship between two measured phenomena.
#
# Simply put, type 1 errors are “false positives” – they happen when the tester validates a statistically significant difference even though there isn’t one.
#
#
# **Type 2 errors** - In the same way that type 1 errors are commonly referred to as “false positives”, type 2 errors are referred to as “false negatives”.
#
# Type 2 errors happen when you inaccurately assume that no winner has been declared between a control version and a variation although there actually is a winner.
#
# In more statistically accurate terms, type 2 errors happen when the null hypothesis is false and you subsequently fail to reject it.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Assignment
#
#
# In this assignment, you will implement a spam mail classification system and explore Type I and Type II errors in the context of classification models. You will use the Spam email dataset from the UCI Machine Learning Repository to train and evaluate your model. The goal is to classify emails as either spam or non-spam and to analyze the types of errors that occur during classification. Specifically, you will focus on Type I errors (false positives, where a non-spam email is classified as spam) and Type II errors (false negatives, where a spam email is classified as non-spam).
#
# go through the dataset details here:
#
# https://archive.ics.uci.edu/dataset/94/spambase
#
#
# You will first split the data into training and testing sets, then build a classification model (Logistic Regression) to predict whether an email is spam. After making predictions, you will compute the confusion matrix, precision, recall, and accuracy to evaluate the model. The primary focus will be on identifying and discussing the impact of Type I and Type II errors in the context of email filtering.

# %% [markdown]
# **Instructions**:
#
# **Data Preparation**: Download the Spambase dataset and load it into your code. Split the data into training and testing sets (70% training, 30% testing). Standardize or normalize the features if necessary.
#
# **Model Building**:
#
# Choose a classification model (Logistic Regression).
# Train the model on the training data and make predictions on the test set.
#
# **Confusion Matrix**: Compute the confusion matrix to observe the true positives, true negatives, false positives, and false negatives. Using the confusion matrix, identify Type I errors (false positives) and Type II errors (false negatives).
#
# **Evaluation Metrics**:
#
# Calculate the accuracy, precision, recall, and F1-score.
# Focus on how Type I errors and Type II errors affect these metrics, and what trade-offs you might need to make.
#
# **Error Analysis**: Analyze the consequences of both types of errors in the context of spam classification. For example, what are the real-world implications of misclassifying a spam email as non-spam (Type II error), or a non-spam email as spam (Type I error)?
#
# **Visualization**: Visualize the confusion matrix using a heatmap.

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/spambase/spambase.data', header=None)

# Display the first few rows of the dataset
print(data.head())

# %%
# Features (All columns except the last one)
X = data.iloc[:, :-1]

# Target (Last column - 1 indicates spam, 0 indicates non-spam)
y = data.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# Feature scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# Build and train the model
model = LogisticRegression()
model.fit(X_train, y_train)

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# %%
import numpy as np

## Fill in the following code:

## calculate confusion matrix
tp =   # True Positives
tn =   # True Negatives
fp =   # False Positives (Type I Error)
fn =   # False Negatives (Type II Error)

# Manual Confusion Matrix
conf_matrix = np.array([[tn, fp],
                                [fn, tp]])

print("Confusion Matrix:")
print(conf_matrix)

# Type I and Type II errors
type_i_error =   # False Positives
type_ii_error =  # False Negatives

print(f"Type I Error (False Positives): {type_i_error}")
print(f"Type II Error (False Negatives): {type_ii_error}")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize confusion matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="YlGnBu", xticklabels=['Non-Spam', 'Spam'], yticklabels=['Non-Spam', 'Spam'])
plt.title('Confusion Matrix - Spam Classification')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# Answer the following:-
#
# Q1. *Which type of error (Type I or Type II) would cause more harm in the context of spam email classification, and why?*
#
# Q2. *How would adjusting the classification threshold impact the number of Type I and Type II errors?*
